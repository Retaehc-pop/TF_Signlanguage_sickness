# %% [markdown]
# **Data preprocessing, Create Label and Features**

# %%
#import dependencies
import cv2
import numpy as np
import os
from matplotlib import pyplot as pyplot
import time
import mediapipe as mp
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
DATA_PATH = os.path.join("DATA_LIB2") # paht of the exported data
sequence_length = 30

# %%
sequences,lables = [], []
actions = np.array(os.listdir(os.path.join(DATA_PATH)))
label_map = {lable:num for num,lable in enumerate(actions)}
for action in actions:
  action_file = os.listdir(os.path.join(DATA_PATH,action))
  for sequence in range(len(action_file)): #should change to the number of file
    window = []
    for frame_num in range(sequence_length):
      res = np.load(os.path.join(DATA_PATH,action,str(sequence),f"{frame_num}.npy"))
      window.append(res)
    sequences.append(window)
    lables.append(label_map[action])
    
X = np.array(sequences)
y = to_categorical(lables).astype(int)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.05)

# %%
# print(X_train.shape)
# print(y_train.shape)
with open("label_map.txt",'w') as file:
  for word in label_map.keys():
    file.write(f"{word}:{label_map[word]}\n")

# %% [markdown]
# **Train the AI**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense,Dropout
from tensorflow.keras.callbacks import TensorBoard
import tensorflowjs as tfjs

# %%
log_dir = os.path.join('logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential() #/
model.add(LSTM(64,return_sequences=True,activation='relu',input_shape=(30,1662))) #frame and all data shape
# model.add(LSTM(128,return_sequences=True,activation='relu')) 
model.add(LSTM(128,return_sequences=True,activation='relu')) # return false because next layer is dense
model.add(LSTM(64,return_sequences=False,activation='relu')) # return false because next layer is dense
model.add(Dense(64,activation='relu')) 
model.add(Dense(64,activation='relu')) 
model.add(Dense(32,activation='relu')) 
model.add(Dense(actions.shape[0],activation='softmax')) # return output by how many action do we have => [0.7,0.1,0.2] / likely be 'hello'

#loss = categorical => multiple class 
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['categorical_accuracy'])
#epochs increase relatively the number of data 
model.fit(X_train,y_train,epochs=50,callbacks=[tb_callback])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 14/14 [==============================] - 10s 348ms/step - loss: 1.9245 - categorical_accuracy: 0.1628
# Epoch 2/50
# 14/14 [==============================] - 3s 215ms/step - loss: 1.3567 - categorical_accuracy: 0.5326
# Epoch 3/50
# 14/14 [==============================] - 3s 221ms/step - loss: 1.0611 - categorical_accuracy: 0.6977
# Epoch 4/50
# 14/14 [==============================] - 3s 206ms/step - loss: 1.3344 - categorical_accuracy: 0.4628
# Epoch 5/50
# 14/14 [==============================] - 3s 215ms/step - loss: 0.6717 - categorical_accuracy: 0.7953
# Epoch 6/50
# 14/14 [==============================] - 3s 204ms/step - loss: 0.5159 - categorical_accuracy: 0.7558
# Epoch 7/50
# 14/14 [==============================] - 3s 225ms/step - loss: 0.4454 - categorical_accuracy: 0.8140
# Epoch 8/50
# 14/14 [==============================] - 3s 229ms/step - loss: 0.2141 - categorical_accuracy: 0.9419
# Epoch 9/50
# 14/14 [==============================] - 3s 202ms/step - loss: 0.1816 - categorical_accuracy: 0.9535
# Epoch 10/50
# 14/14 [==============================] - 3s 238ms/step - loss: 1.0110 - categorical_accuracy: 0.7209
# Epoch 11/50
# 14/14 [==============================] - 3s 224ms/step - loss: 0.3646 - categorical_accuracy: 0.9070
# Epoch 12/50
# 14/14 [==============================] - 3s 212ms/step - loss: 1.1755 - categorical_accuracy: 0.8279
# Epoch 13/50
# 14/14 [==============================] - 3s 213ms/step - loss: 1.2271 - categorical_accuracy: 0.5442
# Epoch 14/50
# 14/14 [==============================] - 3s 196ms/step - loss: 0.8428 - categorical_accuracy: 0.6744
# Epoch 15/50
# 14/14 [==============================] - 3s 222ms/step - loss: 2.9702 - categorical_accuracy: 0.2884
# Epoch 16/50
# 14/14 [==============================] - 3s 203ms/step - loss: 2.8004 - categorical_accuracy: 0.3140
# Epoch 17/50
# 14/14 [==============================] - 3s 237ms/step - loss: 1.4217 - categorical_accuracy: 0.3233
# Epoch 18/50
# 14/14 [==============================] - 3s 226ms/step - loss: 1.2412 - categorical_accuracy: 0.4000
# Epoch 19/50
# 14/14 [==============================] - 3s 241ms/step - loss: 1.0633 - categorical_accuracy: 0.5023
# Epoch 20/50
# 14/14 [==============================] - 3s 211ms/step - loss: 0.9705 - categorical_accuracy: 0.5512
# Epoch 21/50
# 14/14 [==============================] - 3s 221ms/step - loss: 0.8360 - categorical_accuracy: 0.7465
# Epoch 22/50
# 14/14 [==============================] - 3s 201ms/step - loss: 0.7875 - categorical_accuracy: 0.7395
# Epoch 23/50
# 14/14 [==============================] - 3s 234ms/step - loss: 0.6691 - categorical_accuracy: 0.8140
# Epoch 24/50
# 14/14 [==============================] - 3s 220ms/step - loss: 0.5676 - categorical_accuracy: 0.8302
# Epoch 25/50
# 14/14 [==============================] - 3s 218ms/step - loss: 0.4363 - categorical_accuracy: 0.8628
# Epoch 26/50
# 14/14 [==============================] - 3s 207ms/step - loss: 0.3931 - categorical_accuracy: 0.8349
# Epoch 27/50
# 14/14 [==============================] - 3s 220ms/step - loss: 0.4849 - categorical_accuracy: 0.8279
# Epoch 28/50
# 14/14 [==============================] - 3s 197ms/step - loss: 0.3541 - categorical_accuracy: 0.8558
# Epoch 29/50
# 14/14 [==============================] - 3s 189ms/step - loss: 0.3641 - categorical_accuracy: 0.8488
# Epoch 30/50
# 14/14 [==============================] - 3s 203ms/step - loss: 0.5995 - categorical_accuracy: 0.8047
# Epoch 31/50
# 14/14 [==============================] - 3s 217ms/step - loss: 0.7631 - categorical_accuracy: 0.7767
# Epoch 32/50
# 14/14 [==============================] - 3s 220ms/step - loss: 0.4532 - categorical_accuracy: 0.8163
# Epoch 33/50
# 14/14 [==============================] - 3s 229ms/step - loss: 0.3359 - categorical_accuracy: 0.8488
# Epoch 34/50
# 14/14 [==============================] - 3s 244ms/step - loss: 0.3077 - categorical_accuracy: 0.9093
# Epoch 35/50
# 14/14 [==============================] - 3s 231ms/step - loss: 0.3094 - categorical_accuracy: 0.9140
# Epoch 36/50
# 14/14 [==============================] - 3s 229ms/step - loss: 0.2860 - categorical_accuracy: 0.9093
# Epoch 37/50
# 14/14 [==============================] - 3s 234ms/step - loss: 0.3672 - categorical_accuracy: 0.8395
# Epoch 38/50
# 14/14 [==============================] - 3s 220ms/step - loss: 0.3010 - categorical_accuracy: 0.8884
# Epoch 39/50
# 14/14 [==============================] - 3s 228ms/step - loss: 1.7811 - categorical_accuracy: 0.9023
# Epoch 40/50
# 14/14 [==============================] - 3s 224ms/step - loss: 13.9964 - categorical_accuracy: 0.4535
# Epoch 41/50
# 14/14 [==============================] - 3s 196ms/step - loss: 2.0214 - categorical_accuracy: 0.3605
# Epoch 42/50
# 14/14 [==============================] - 3s 209ms/step - loss: 3.8128 - categorical_accuracy: 0.2977
# Epoch 43/50
# 14/14 [==============================] - 3s 218ms/step - loss: 1.7486 - categorical_accuracy: 0.2419
# Epoch 44/50
# 14/14 [==============================] - 3s 223ms/step - loss: 1.3419 - categorical_accuracy: 0.4558
# Epoch 45/50
# 14/14 [==============================] - 3s 231ms/step - loss: 1.4374 - categorical_accuracy: 0.4465
# Epoch 46/50
# 14/14 [==============================] - 3s 207ms/step - loss: 1.2659 - categorical_accuracy: 0.4953
# Epoch 47/50
# 14/14 [==============================] - 3s 211ms/step - loss: 1.1972 - categorical_accuracy: 0.4767
# Epoch 48/50
# 14/14 [==============================] - 3s 235ms/step - loss: 1.5337 - categorical_accuracy: 0.3256
# Epoch 49/50
# 14/14 [==============================] - 3s 215ms/step - loss: 1.6429 - categorical_accuracy: 0.3000
# Epoch 50/50
# 14/14 [==============================] - 3s 212ms/step - loss: 1.5302 - categorical_accuracy: 0.3372

# %%
model.fit(X_train,y_train,epochs=10,callbacks=[tb_callback])
# Out:
# Epoch 1/10
# 14/14 [==============================] - 5s 337ms/step - loss: 1.5861 - categorical_accuracy: 0.2791
# Epoch 2/10
# 14/14 [==============================] - 3s 235ms/step - loss: 1.4254 - categorical_accuracy: 0.4256
# Epoch 3/10
# 14/14 [==============================] - 3s 222ms/step - loss: 1.0595 - categorical_accuracy: 0.5558
# Epoch 4/10
# 14/14 [==============================] - 3s 223ms/step - loss: 0.8404 - categorical_accuracy: 0.7395
# Epoch 5/10
# 14/14 [==============================] - 3s 249ms/step - loss: 0.8681 - categorical_accuracy: 0.7349
# Epoch 6/10
# 14/14 [==============================] - 3s 219ms/step - loss: 0.7422 - categorical_accuracy: 0.8047
# Epoch 7/10
# 14/14 [==============================] - 3s 212ms/step - loss: 0.7184 - categorical_accuracy: 0.7698
# Epoch 8/10
# 14/14 [==============================] - 3s 220ms/step - loss: 0.6825 - categorical_accuracy: 0.8116
# Epoch 9/10
# 14/14 [==============================] - 3s 221ms/step - loss: 0.7592 - categorical_accuracy: 0.7651
# Epoch 10/10
# 14/14 [==============================] - 3s 210ms/step - loss: 0.6883 - categorical_accuracy: 0.8023

# %%
#watch the log
# %cd logs/train
# %tensorboard --logdir=.
# Out:
# d:\PROJECTS\SPACE_AC\Asclepius\TF_Signlanguage_sickness\logs\train
# UsageError: Line magic function `%tensorboard` not found.

# %%
# %cd ..
# Out:
# d:\PROJECTS\SPACE_AC\Asclepius\TF_Signlanguage_sickness

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 64)            442112
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 128)           98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 600,901
# Trainable params: 600,901
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **save module**

# %%
model.save("illness.h5")
tfjs.converters.save_keras_model(model, "illness")

# %%
# reload model weight
model.load_weights('action.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36048/3828712627.py in <module>
#       1 # reload model weight
# ----> 2 model.load_weights('action.h5')
#
# ~\.conda\envs\tf37\lib\site-packages\keras-2.6.0-py3.7.egg\keras\engine\training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2352             'first, then load the weights.')
#    2353       self._assert_weights_created()
# -> 2354       with h5py.File(filepath, 'r') as f:
#    2355         if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2356           f = f['model_weights']
#
# ~\.conda\envs\tf37\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     425                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     426                                fs_persist=fs_persist, fs_threshold=fs_threshold),
# --> 427                                swmr=swmr)
#     428
#     429             if isinstance(libver, tuple):
#
# ~\.conda\envs\tf37\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     188         if swmr and swmr_support:
#     189             flags |= h5f.ACC_SWMR_READ
# --> 190         fid = h5f.open(name, flags, fapl=fapl)
#     191     elif mode == 'r+':
#     192         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'action.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
#load model
from tensorflow import keras
model = keras.models.load_model('action.h5')
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# **eval**

# %%
from sklearn.metrics import multilabel_confusion_matrix,accuracy_score
yhat = model.predict(X_test)
ytrue = np.argmax(y_test,axis=1).tolist()
yhat = np.argmax(yhat,axis=1).tolist()
multilabel_confusion_matrix(ytrue,yhat)
accuracy_score(ytrue,yhat)
# Out:
# 0.6956521739130435

# %%
mp_holistic = mp.solutions.holistic # holistic module
mp_drawing = mp.solutions.drawing_utils # drawing utilities
def mediapipe_detection(image,model):
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB) # color conversion
  image.flags.writeable = False
  results = model.process(image) # process image
  image.flags.writeable = True
  image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR) # color conversion
  return image,results
def draw_landmarks(image,result):
  mp_drawing.draw_landmarks(image,result.face_landmarks,mp_holistic.FACEMESH_CONTOURS)
  mp_drawing.draw_landmarks(image,result.pose_landmarks,mp_holistic.POSE_CONNECTIONS)
  mp_drawing.draw_landmarks(image,result.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS)
  mp_drawing.draw_landmarks(image,result.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS)
def draw_styles_landmarked(image,result):
  mp_drawing.draw_landmarks(image,result.face_landmarks,mp_holistic.FACEMESH_CONTOURS,
                            mp_drawing.DrawingSpec(color=(80,110,10),thickness=1,circle_radius=1),
                            mp_drawing.DrawingSpec(color=(80,256,10),thickness=1,circle_radius=1))
  mp_drawing.draw_landmarks(image,result.pose_landmarks,mp_holistic.POSE_CONNECTIONS)
  mp_drawing.draw_landmarks(image,result.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS)
  mp_drawing.draw_landmarks(image,result.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS)
def extract_keypoint(result):
  pose = np.array([[res.x,res.y,res.z,res.visibility] for res in result.pose_landmarks.landmark]).flatten() if result.pose_landmarks else np.zeros(33*4)
  face = np.array([[res.x,res.y,res.z] for res in result.face_landmarks.landmark]).flatten() if result.face_landmarks else np.zeros(468*3)
  left_hand = np.array([[res.x,res.y,res.z] for res in result.left_hand_landmarks.landmark]).flatten() if result.left_hand_landmarks else np.zeros(21*3)
  right_hand = np.array([[res.x,res.y,res.z] for res in result.right_hand_landmarks.landmark]).flatten() if result.right_hand_landmarks else np.zeros(21*3)
  return np.concatenate([pose,face,left_hand,right_hand])
colors = [(245,117,16), (117,245,16), (16,117,245),(44,217,235)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        # Draw landmarks
        draw_landmarks(image, results)
        # 2. Prediction logic
        keypoints = extract_keypoint(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                            sequence = []
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]
            
            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36048/3797304724.py in <module>
#      40
#      41             # Viz probabilities
# ---> 42             image = prob_viz(res, actions, image, colors)
#      43
#      44         cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
#
# ~\AppData\Local\Temp/ipykernel_36048/3978197911.py in prob_viz(res, actions, input_frame, colors)
#      30     output_frame = input_frame.copy()
#      31     for num, prob in enumerate(res):
# ---> 32         cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#      33         cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#      34
#
# IndexError: list index out of range

# %%
cap.release()
cv2.destroyAllWindows()
